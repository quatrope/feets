# %%
import wilyapi

# %%
api = wilyapi.WilyAPI()

# %%
df = api.metric_report("mi", subdir="feets")

# %%
df = api.metric_plot("mi", subdir="feets")

# %%
import seaborn as sns

# %%
df = api.metric_report("mi", subdir="feets")

# %%
df.plot()
# Out:
# <Axes: xlabel='Revision,Date'>
